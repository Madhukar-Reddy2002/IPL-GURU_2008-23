# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./new.csv', low_memory=False)
df2 = pd.read_csv('./data/ipl.csv', low_memory=False)
df.head()
# Out:
#    match_id  innings    batting_team         bowling_team       striker  \
# 0   1370353        1  Gujarat Titans  Chennai Super Kings       WP Saha
# 1   1370353        1  Gujarat Titans  Chennai Super Kings       WP Saha
# 2   1370353        1  Gujarat Titans  Chennai Super Kings       WP Saha
# 3   1370353        1  Gujarat Titans  Chennai Super Kings  Shubman Gill
# 4   1370353        1  Gujarat Titans  Chennai Super Kings       WP Saha
#
#     non_striker     bowler  runs_off_bat  extras  wides  ...  toss_decision  \
# 0  Shubman Gill  DL Chahar             0       0    NaN  ...          field
# 1  Shubman Gill  DL Chahar             0       0    NaN  ...          field
# 2  Shubman Gill  DL Chahar             1       0    NaN  ...          field
# 3       WP Saha  DL Chahar             1       0    NaN  ...          field
# 4  Shubman Gill  DL Chahar             1       0    NaN  ...          field
#
# ...

# %%
# Create a dictionary mapping match_id with the first startdate for each match_id
match_id_to_startdate = df2.groupby('match_id')['start_date'].first().to_dict()

print(match_id_to_startdate)
# Out:
# {335982: '18-04-2008', 335983: '19-04-2008', 335984: '19-04-2008', 335985: '20-04-2008', 335986: '20-04-2008', 335987: '21-04-2008', 335988: '22-04-2008', 335989: '23-04-2008', 335990: '24-04-2008', 335991: '25-04-2008', 335992: '26-04-2008', 335993: '26-04-2008', 335994: '27-04-2008', 335995: '27-04-2008', 335996: '28-04-2008', 335997: '29-04-2008', 335998: '30-04-2008', 335999: '01-05-2008', 336000: '01-05-2008', 336001: '02-05-2008', 336002: '25-05-2008', 336003: '03-05-2008', 336004: '04-05-2008', 336005: '04-05-2008', 336006: '05-05-2008', 336007: '06-05-2008', 336008: '07-05-2008', 336009: '08-05-2008', 336010: '08-05-2008', 336011: '09-05-2008', 336012: '28-05-2008', 336013: '10-05-2008', 336014: '11-05-2008', 336015: '11-05-2008', 336016: '12-05-2008', 336017: '13-05-2008', 336018: '14-05-2008', 336019: '28-05-2008', 336020: '15-05-2008', 336021: '16-05-2008', 336022: '17-05-2008', 336023: '17-05-2008', 336024: '18-05-2008', 336025: '18-05-2008', 336026: '19-05-2008', 336027:
# ...

# %%
df['start_date'] = df['match_id'].map(match_id_to_startdate)

# %%
df["season"].unique()
# Out:
# array(['2023', '2022', '2021', '2020/21', '2019', '2018', '2017', '2016',
#        '2015', '2014', '2013', '2012', '2011', '2009/10', '2009',
#        '2007/08'], dtype=object)

# %%
filtered_df = df[(df["season"] == "2023") & (df["bowler"] == "MM Sharma") & (df["wicket_type"].notna()) & (df["wicket_type"] != "run out")]
filtered_df[["wicket_type","bowler" ]].shape
# Out:
# (27, 2)

# %%
df['over'] = df['over'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243816 entries, 0 to 243815
# Data columns (total 32 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          243816 non-null  int64
#  1   innings           243816 non-null  int64
#  2   batting_team      243816 non-null  object
#  3   bowling_team      243816 non-null  object
#  4   striker           243816 non-null  object
#  5   non_striker       243816 non-null  object
#  6   bowler            243816 non-null  object
#  7   runs_off_bat      243816 non-null  int64
#  8   extras            243816 non-null  int64
#  9   wides             7652 non-null    float64
#  10  noballs           1018 non-null    float64
#  11  byes              628 non-null     float64
#  12  legbyes           3778 non-null    float64
#  13  wicket_type       12067 non-null   object
#  14  player_dismissed  12067 non-null   object
#  15  season            243816 non-null  object
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('./new.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df = pd.read_csv('./new1.csv')
#       2 df.head()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df["team2"].unique()
# Out:
# array(['Chennai Super Kings', 'Mumbai Indians', 'Lucknow Super Giants',
#        'Gujarat Titans', 'Delhi Capitals', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Royal Challengers Bangalore', 'Punjab Kings',
#        'Sunrisers Hyderabad', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Rising Pune Supergiants', 'Gujarat Lions', 'Pune Warriors',
#        'Deccan Chargers', 'Kochi Tuskers Kerala'], dtype=object)

# %%
df["winner"] = df["winner"].fillna("Draw")

# %%
df["runners"].unique()
# Out:
# array(['Gujarat Lions', 'Mumbai Indians', 'Lucknow Super Giants',
#        'Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Delhi Capitals', 'Kolkata Knight Riders', 'Kings XI Punjab',
#        'Rajasthan Royals', 'Chennai Super Kings',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Kochi Tuskers Kerala'],
#       dtype=object)

# %%
df = df.replace('Rising Pune Supergiant','Rising Pune Supergiants')
df = df.replace('Delhi Daredevils','Delhi Capitals')
df = df.replace('Gujarat Titans','Gujarat Lions')
df = df.replace('Punjab Kings','Kings XI Punjab')
df = df.replace('Deccan Chargers','Sunrisers Hyderabad')
df["winner"] = df["winner"].fillna("Draw")

# %%
df.to_csv("new2.csv", index=False)

# %%
# Setting "runners" to "Draw" where "winner" is "Draw"
df.loc[df["winner"] == "Draw", "runners"] = "Draw"

# %%
import pandas as pd
df = pd.read_csv('./test.csv')
df.head()
# Out:
#         id        date  store_nbr      family  onpromotion
# 0  3000888  2017-08-16          1  AUTOMOTIVE            0
# 1  3000889  2017-08-16          1   BABY CARE            0
# 2  3000890  2017-08-16          1      BEAUTY            2
# 3  3000891  2017-08-16          1   BEVERAGES           20
# 4  3000892  2017-08-16          1       BOOKS            0

# %%
import datetime as dt
# Convert 'date' column to datetime type
df['date'] = pd.to_datetime(df['date'])

# Extract year and store it in a new column named 'day'
df['year'] = df['date'].dt.year
# Extract month, weekday, quarter, and day and store them in new columns
df['month'] = df['date'].dt.month
df['weekday'] = df['date'].dt.weekday
df['quarter'] = df['date'].dt.quarter
df['day'] = df['date'].dt.day

print(df.head())
# Out:
#         id       date  store_nbr      family  onpromotion  day  year  month  \
# 0  3000888 2017-08-16          1  AUTOMOTIVE            0   16  2017      8
# 1  3000889 2017-08-16          1   BABY CARE            0   16  2017      8
# 2  3000890 2017-08-16          1      BEAUTY            2   16  2017      8
# 3  3000891 2017-08-16          1   BEVERAGES           20   16  2017      8
# 4  3000892 2017-08-16          1       BOOKS            0   16  2017      8
#
#    weekday  quarter
# 0        2        3
# 1        2        3
# 2        2        3
# 3        2        3
# 4        2        3

# %%
df.to_csv("naya.csv", index=False)
